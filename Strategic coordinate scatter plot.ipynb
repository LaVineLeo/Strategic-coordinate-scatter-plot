# %%
import pandas as pd
import seaborn as sns
import plotly.express as px
import numpy as np

import numpy as np; np.random.seed(1)
from scipy.spatial import ConvexHull
import matplotlib.pyplot as plt

# %%
# iris_df=sns.load_dataset('iris')

 
#读取文件
readFileName="pca战略坐标2-改.xlsx"
#读取excel
df=pd.read_excel(readFileName)

penguins_df=df

df.head(10)
# Out:
#              Keywords Cluster     Density  Concentricity    Size  Unnamed: 5  \
# 0  Project Management      C3  121.389229       5.645687  76.176       76176
# 1      Infrastructure      C1  127.085739      39.270348  71.824       71824
# 2     Risk Management      C4  101.562080      34.683701  40.000       40000
# 3      Sustainability      C7   58.855152      16.872940  24.336       24336
# 4               China      C7  128.052216      55.110615  24.336       24336
# 5     Risk Allocation      C6  109.325562      69.570755  23.104       23104
# 6   Concession Period      C6   83.397408      12.914725  17.424       17424
# 7               India      C6    6.181371      -8.690945  11.664       11664
# 8      Private Sector      C5   69.421036      21.963121   9.216        9216
# 9          Innovation      C0   57.117580     -58.960876   7.744        7744
#
#     Size3  Size2  xian1  xian2
# 0  76.176    276      0      0
# 1  71.824    268      0      0
# ...

# %%
fig, ax = plt.subplots(figsize=(6,5),dpi=200)
scatter = sns.scatterplot(data=penguins_df,x="Concentricity",y="Density",hue="Cluster",
                          size="Size",ec="k",alpha=.9,ax=ax)
scatter.legend()
ax.text(.91,-.1,'\nVisualization by DataCharm',transform = ax.transAxes,
        ha='center', va='center',fontsize = 7,color='black')
# Out:
# Text(0.91, -0.1, '\nVisualization by DataCharm')

# %%
fig, ax = plt.subplots(figsize=(6,5),dpi=200)
scatter = sns.scatterplot(data=penguins_df,x="concentricity",y="Density",hue="Cluster",
                          size="Size",ec="k",alpha=.9,ax=ax)
scatter.legend()
ax.text(.91,-.1,'\nVisualization by DataCharm',transform = ax.transAxes,
        ha='center', va='center',fontsize = 7,color='black')

# #变量  # 对散点图中的每一个点进行文字标注
# x, y = df['bill_length_mm'], df['bill_depth_mm']
# label = df['species']
# # 对散点图中的每一个点进行文字标注
#  ## 固定代码，无需深究，拿来即用
# for a,b,l in zip(x,y,label): # zip 拉链函数将其配对组合
#     plt.text(a, b+0.1, '%s.' % l, ha='center', va='bottom', 
#                                              fontsize=14)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [7], in <cell line: 2>()
#       1 fig, ax = plt.subplots(figsize=(6,5),dpi=200)
# ----> 2 scatter = sns.scatterplot(data=penguins_df,x="concentricity",y="Density",hue="Cluster",
#       3                           size="Size",ec="k",alpha=.9,ax=ax)
#       4 scatter.legend()
#       5 ax.text(.91,-.1,'\nVisualization by DataCharm',transform = ax.transAxes,
#       6         ha='center', va='center',fontsize = 7,color='black')
#
# File ~\AppData\Roaming\Python\Python39\site-packages\seaborn\relational.py:736, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     726 def scatterplot(
#     727     data=None, *,
#     728     x=None, y=None, hue=None, size=None, style=None,
#    (...)
#     732     **kwargs
#     733 ):
# ...

# %% [markdown]
# # 2. 宏观战略图

# %%
# iris_df=sns.load_dataset('iris')

 
#读取文件
readFileName="pca战略坐标2-改.xlsx"
#读取excel
df=pd.read_excel(readFileName)

penguins_df=df


# 
#添加特定的分割线版本
#中文乱码解决
from pylab import mpl
mpl.rcParams['font.sans-serif'] = ['Times New Roman'] # 指定默认字体
mpl.rcParams['axes.unicode_minus'] = False # 解决保存图像是负号'-'显示为方块的问题


fig, ax = plt.subplots(figsize=(6,5),dpi=200)
#颜色定制
#3种颜色
# palette = ("#FF8C00", "#A034F0", "#159090")
#八种颜色
palette1 = ("#00cbcc", "#515151", "#b177de","#f14040","#7d4e4e","#cc9900","#37ad6b","#1a6fdf")
#x=战略坐标偏移值  y=战略坐标重要值  hue为分类

scatter = sns.scatterplot(data=penguins_df,x="Concentricity",y="Density",hue="Cluster",palette=palette1,
                          size="Size",ec="k",alpha=1,linewidth=0.5,ax=ax)

# scatter.legend()
# ax.text(.91,-.1,'\nVisualization by DataCharm',transform = ax.transAxes,
#  ha='center', va='center',fontsize = 715,color='black')

#自定义标签

handles,labels = scatter.get_legend_handles_labels()
labels_size =  labels[4:]

#添加单位
# labels_size = [str(int(i)/1000)+" kg" for i in labels_size]
#改标签 
scatter.legend(handles=handles[1:4] + handles[4:], labels=labels[1:4] + labels_size ,ncol=1,loc="lower right",title="Cluster",
               frameon=True,fontsize=5,markerscale=1,bbox_to_anchor=(1, 0.0))

plt.style.use('default')

# 添加特定分割线
 ## vlines: vertical 垂直于 x 轴的线，在变量'经济总量'的均值处开始画，
   ## y 轴的范围[1.5, 3]
  ## y 轴的范围[ymin, ymax]
    
    
#1添加象限说明  第一象限
# 在2,1处画个圆点，添加注释
x1=-100
y1=200

#可以加一个圆圈
# ax.plot([x2], [y2], 'o')
ax.plot([x1], [y1])
ax.annotate('Edge&Mature Research', xy=(x1, y1), xytext=(x1, y1),fontsize=8,
            arrowprops=dict(facecolor='black', shrink=0.05,color='red'))

#2添加象限说明  第二象限
# 在2,1处画个圆点，添加注释
x2=70
y2=200

ax.plot([x2], [y2])
ax.annotate('Core&Mature Research', xy=(x2, y2), xytext=(x2, y2),fontsize=8,
            arrowprops=dict(facecolor='black', shrink=0.05,color='red'))

#3添加象限说明  第三象限
# 在2,1处画个圆点，添加注释
x3=-100
y3=-200
ax.plot([x3], [y3])
ax.annotate('Edge&Non-mature Research', xy=(x3, y3), xytext=(x3, y3),fontsize=8,
            arrowprops=dict(facecolor='black', shrink=0.05,color='red'))

#4添加象限说明  第四象限
# 在2,1处画个圆点，添加注释
x4=40
y4=-200
ax.plot([x4], [y4])
ax.annotate('Core&Non-mature Research', xy=(x4, y4), xytext=(x4, y4),fontsize=8,
            arrowprops=dict(facecolor='black', shrink=0.05,color='red'))
    
    
    
#读取向心度和中心度的平均值
plt.vlines(x=df['xian1'].mean(), ymin=-200, ymax=200, 
           colors='black', linewidth=1, linestyles='--')
plt.hlines(y=df['xian2'].mean(), xmin=-150, xmax=150,
           colors='black', linewidth=1, linestyles='--')
#网格线开关
# plt.grid(True)



from pylab import mpl
mpl.rcParams['font.sans-serif'] = ['Times New Roman'] # 指定默认字体
mpl.rcParams['axes.unicode_minus'] = False # 解决保存图像是负号'-'显示为方块的问题
plt.title('Strategy Coordinate of Theme Words',fontsize=15)
plt.savefig('战略图_宏观.png', dpi=600, bbox_inches='tight',font_scale=1)
plt.show()
# Out:
# C:\Users\69493\AppData\Local\Temp\ipykernel_32028\1257585283.py:62: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   ax.annotate('Edge&Mature Research', xy=(x1, y1), xytext=(x1, y1),fontsize=8,
# C:\Users\69493\AppData\Local\Temp\ipykernel_32028\1257585283.py:71: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   ax.annotate('Core&Mature Research', xy=(x2, y2), xytext=(x2, y2),fontsize=8,
# C:\Users\69493\AppData\Local\Temp\ipykernel_32028\1257585283.py:79: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   ax.annotate('Edge&Non-mature Research', xy=(x3, y3), xytext=(x3, y3),fontsize=8,
# C:\Users\69493\AppData\Local\Temp\ipykernel_32028\1257585283.py:87: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   ax.annotate('Core&Non-mature Research', xy=(x4, y4), xytext=(x4, y4),fontsize=8,
# ...

# %%
# iris_df=sns.load_dataset('iris')

 
#读取文件
readFileName="pca战略坐标2-改.xlsx"
#读取excel
df=pd.read_excel(readFileName)

penguins_df=df


# 
#添加特定的分割线版本
#中文乱码解决
from pylab import mpl
mpl.rcParams['font.sans-serif'] = ['Times New Roman'] # 指定默认字体
mpl.rcParams['axes.unicode_minus'] = False # 解决保存图像是负号'-'显示为方块的问题


fig, ax = plt.subplots(figsize=(6,5),dpi=200)
#颜色定制
#3种颜色
# palette = ("#FF8C00", "#A034F0", "#159090")
#八种颜色
palette1 = ("#00cbcc", "#515151", "#b177de","#f14040","#7d4e4e","#cc9900","#37ad6b","#1a6fdf")
#x=战略坐标偏移值  y=战略坐标重要值  hue为分类

scatter = sns.scatterplot(data=penguins_df,x="Concentricity",y="Density",hue="Cluster",palette=palette1,
                          size="Size",ec="k",alpha=1,linewidth=0.5,ax=ax)

# scatter.legend()
# ax.text(.91,-.1,'\nVisualization by DataCharm',transform = ax.transAxes,
#  ha='center', va='center',fontsize = 715,color='black')

#自定义标签

handles,labels = scatter.get_legend_handles_labels()
labels_size =  labels[4:]

#添加单位
# labels_size = [str(int(i)/1000)+" kg" for i in labels_size]
#改标签 
scatter.legend(handles=handles[1:4] + handles[4:], labels=labels[1:4] + labels_size ,ncol=1,loc="lower right",title="Cluster",
               frameon=True,fontsize=5,markerscale=1,bbox_to_anchor=(1, 0.0))

plt.style.use('default')

# 添加特定分割线
 ## vlines: vertical 垂直于 x 轴的线，在变量'经济总量'的均值处开始画，
   ## y 轴的范围[1.5, 3]
  ## y 轴的范围[ymin, ymax]
    
    
#1添加象限说明  第一象限
# 在2,1处画个圆点，添加注释
x1=-100
y1=200

#可以加一个圆圈
# ax.plot([x2], [y2], 'o')
ax.plot([x1], [y1])
ax.annotate('Edge&Mature Research', xy=(x1, y1), xytext=(x1, y1),fontsize=8,
            arrowprops=dict(facecolor='black', shrink=0.05,color='red'))

#2添加象限说明  第二象限
# 在2,1处画个圆点，添加注释
x2=70
y2=200

ax.plot([x2], [y2])
ax.annotate('Core&Mature Research', xy=(x2, y2), xytext=(x2, y2),fontsize=8,
            arrowprops=dict(facecolor='black', shrink=0.05,color='red'))

#3添加象限说明  第三象限
# 在2,1处画个圆点，添加注释
x3=-100
y3=-200
ax.plot([x3], [y3])
ax.annotate('Edge&Non-mature Research', xy=(x3, y3), xytext=(x3, y3),fontsize=8,
            arrowprops=dict(facecolor='black', shrink=0.05,color='red'))

#4添加象限说明  第四象限
# 在2,1处画个圆点，添加注释
x4=40
y4=-200
ax.plot([x4], [y4])
ax.annotate('Core&Non-mature Research', xy=(x4, y4), xytext=(x4, y4),fontsize=8,
            arrowprops=dict(facecolor='black', shrink=0.05,color='red'))
    
 ##################################################################################################   
 #   制作聚类图  凸形边
df0=pd.read_excel('pca战略坐标2-改.xlsx',sheet_name='C0')
df1=pd.read_excel('pca战略坐标2-改.xlsx',sheet_name='C1')
df2=pd.read_excel('pca战略坐标2-改.xlsx',sheet_name='C2')
df3=pd.read_excel('pca战略坐标2-改.xlsx',sheet_name='C3')
df4=pd.read_excel('pca战略坐标2-改.xlsx',sheet_name='C4')
df5=pd.read_excel('pca战略坐标2-改.xlsx',sheet_name='C5')
df6=pd.read_excel('pca战略坐标2-改.xlsx',sheet_name='C6')
df7=pd.read_excel('pca战略坐标2-改.xlsx',sheet_name='C7')

x0=df0['Concentricity']
y0=df0['Density']

x1=df1['Concentricity']
y1=df1['Density']

x2=df2['Concentricity']
y2=df2['Density']

x3=df3['Concentricity']
y3=df3['Density']

x4=df4['Concentricity']
y4=df4['Density']

x5=df5['Concentricity']
y5=df5['Density']

x6=df6['Concentricity']
y6=df6['Density']

x7=df7['Concentricity']
y7=df7['Density']

# x1=df['Concentricity']
# y1=df['Density']
#定义凸边
def encircle(x,y, ax=None, **kw):
    if not ax: ax=plt.gca()
    #计算凸边    
    p = np.c_[x,y]
    hull = ConvexHull(p)
    #加边界
    poly = plt.Polygon(p[hull.vertices,:], **kw)
    ax.add_patch(poly)
#ec是线 fc是颜色
encircle(x0, y0, ec="k", fc="#37ad6b", alpha=0.15) 
encircle(x2, y2, ec="k", fc="#515151",alpha=0.15) 
encircle(x3, y3, ec="k", fc="#00cbcc",alpha=0.15)   
encircle(x4, y4, ec="k", fc="#b177de",alpha=0.15)   
encircle(x5, y5, ec="k", fc="#cc9900",alpha=0.15)   
encircle(x6, y6, ec="k", fc="#7d4e4e",alpha=0.15)   
encircle(x7, y7, ec="k", fc="#f14040",alpha=0.15)   
 ##################################################################################################      
    
plt.vlines(x=df['xian1'].mean(), ymin=-200, ymax=200, 
           colors='black', linewidth=1, linestyles='--')
plt.hlines(y=df['xian2'].mean(), xmin=-150, xmax=150,
           colors='black', linewidth=1, linestyles='--')
#网格线开关
# plt.grid(True)



from pylab import mpl
mpl.rcParams['font.sans-serif'] = ['Times New Roman'] # 指定默认字体
mpl.rcParams['axes.unicode_minus'] = False # 解决保存图像是负号'-'显示为方块的问题
plt.title('Strategy Coordinate of Theme Words',fontsize=15)
plt.savefig('战略图_宏观聚类.png', dpi=600, bbox_inches='tight',font_scale=1)
plt.show()
# Out:
# C:\Users\69493\AppData\Local\Temp\ipykernel_32028\3309682297.py:62: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   ax.annotate('Edge&Mature Research', xy=(x1, y1), xytext=(x1, y1),fontsize=8,
# C:\Users\69493\AppData\Local\Temp\ipykernel_32028\3309682297.py:71: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   ax.annotate('Core&Mature Research', xy=(x2, y2), xytext=(x2, y2),fontsize=8,
# C:\Users\69493\AppData\Local\Temp\ipykernel_32028\3309682297.py:79: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   ax.annotate('Edge&Non-mature Research', xy=(x3, y3), xytext=(x3, y3),fontsize=8,
# C:\Users\69493\AppData\Local\Temp\ipykernel_32028\3309682297.py:87: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   ax.annotate('Core&Non-mature Research', xy=(x4, y4), xytext=(x4, y4),fontsize=8,
# ...

# %% [markdown]
# # 3. C0散点图

# %%
#读取文件
readFileName="pca战略坐标2-改.xlsx"
#读取excel
biaoname= sheet_name="C0"
df=pd.read_excel(readFileName, biaoname)

penguins_df=df

df.head(10)


#添加特定的分割线版本
#中文乱码解决
from pylab import mpl
mpl.rcParams['font.sans-serif'] = ['Times New Roman'] # 指定默认字体
mpl.rcParams['axes.unicode_minus'] = False # 解决保存图像是负号'-'显示为方块的问题


fig, ax = plt.subplots(figsize=(6,5),dpi=200)
#颜色定制
#3种颜色
# palette = ("#FF8C00", "#A034F0", "#159090")
palette = ("#37ad6b")
#八种颜色
# palette = ("#FFBE0B", "#FB5607", "#FF006E","#8338EC","#3A86FF","#8338EC","#001524","#15616D")
#x=战略坐标偏移值  y=战略坐标重要值  hue为分类
sns.color_palette("pastel")
scatter = sns.scatterplot(data=penguins_df,x="Concentricity",y="Density",color=palette,
                          size="Size",ec="k",alpha=.9,ax=ax,linewidth=1)
    
scatter.legend()
# ax.text(.91,-.1,'\nVisualization by DataCharm',transform = ax.transAxes,
#         ha='center', va='center',fontsize = 7,color='black')

#自定义标签

handles,labels = scatter.get_legend_handles_labels()
labels_size =  labels[5:]

#添加单位
# labels_size = [str(int(i)/1000)+" kg" for i in labels_size]

scatter.legend(handles=handles[1:4] + handles[5:], labels=labels[1:4] + labels_size ,ncol=1,loc="lower right",title="Size",
               frameon=True,fontsize=7,markerscale=1,bbox_to_anchor=(1, 0.0))

plt.style.use('default')

# 添加特定分割线
 ## vlines: vertical 垂直于 x 轴的线，在变量'经济总量'的均值处开始画，
   ## y 轴的范围[1.5, 3]
  ## y 轴的范围[ymin, ymax]
    
    
#1添加象限说明  第一象限
# 在2,1处画个圆点，添加注释
x1=-100
y1=200

#可以加一个圆圈
# ax.plot([x2], [y2], 'o')
ax.plot([x1], [y1])
ax.annotate('Edge&Mature Research', xy=(x1, y1), xytext=(x1, y1),fontsize=8,
            arrowprops=dict(facecolor='black', shrink=0.05,color='red'))

#2添加象限说明  第二象限
# 在2,1处画个圆点，添加注释
x2=70
y2=200

ax.plot([x2], [y2])
ax.annotate('Core&Mature Research', xy=(x2, y2), xytext=(x2, y2),fontsize=8,
            arrowprops=dict(facecolor='black', shrink=0.05,color='red'))

#3添加象限说明  第三象限
# 在2,1处画个圆点，添加注释
x3=-100
y3=-180
ax.plot([x3], [y3])
ax.annotate('Edge&Non-mature Research', xy=(x3, y3), xytext=(x3, y3),fontsize=8,
            arrowprops=dict(facecolor='black', shrink=0.05,color='red'))

#4添加象限说明  第四象限
# 在2,1处画个圆点，添加注释
x4=40
y4=-180
ax.plot([x4], [y4])
ax.annotate('Core&Non-mature Research', xy=(x4, y4), xytext=(x4, y4),fontsize=8,
            arrowprops=dict(facecolor='black', shrink=0.05,color='red'))
  
    
 ##################################################################################################   
 #   制作聚类图  凸形边
x1=df['Concentricity']
y1=df['Density']

# plt.scatter(x2, y2)
x1=df['Concentricity']
y1=df['Density']
#定义凸边
def encircle(x,y, ax=None, **kw):
    if not ax: ax=plt.gca()
    #计算凸边    
    p = np.c_[x,y]
    hull = ConvexHull(p)
    #加边界
    poly = plt.Polygon(p[hull.vertices,:], **kw)
    ax.add_patch(poly)
#ec是线 fc是颜色
encircle(x1, y1, ec="k", fc=palette, alpha=0.3)
# encircle(x2, y2, ec="orange", fc="none")   
 ##################################################################################################       

plt.vlines(x=df['xian1'].mean(), ymin=-200, ymax=200, 
           colors='black', linewidth=1, linestyles='--')
plt.hlines(y=df['xian2'].mean(), xmin=-150, xmax=150,
           colors='black', linewidth=1, linestyles='--')
#网格线开关
# plt.grid(True)

from pylab import mpl
mpl.rcParams['font.sans-serif'] = ['Times New Roman'] # 指定默认字体
mpl.rcParams['axes.unicode_minus'] = False # 解决保存图像是负号'-'显示为方块的问题
plt.title(biaoname+' '+'Strategy Coordinate',fontsize=15)
plt.savefig('战略图'+'_'+biaoname+'.png', dpi=600, bbox_inches='tight',font_scale=1)
plt.show()
# Out:
# C:\Users\69493\AppData\Local\Temp\ipykernel_32028\3856223466.py:62: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   ax.annotate('Edge&Mature Research', xy=(x1, y1), xytext=(x1, y1),fontsize=8,
# C:\Users\69493\AppData\Local\Temp\ipykernel_32028\3856223466.py:71: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   ax.annotate('Core&Mature Research', xy=(x2, y2), xytext=(x2, y2),fontsize=8,
# C:\Users\69493\AppData\Local\Temp\ipykernel_32028\3856223466.py:79: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   ax.annotate('Edge&Non-mature Research', xy=(x3, y3), xytext=(x3, y3),fontsize=8,
# C:\Users\69493\AppData\Local\Temp\ipykernel_32028\3856223466.py:87: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   ax.annotate('Core&Non-mature Research', xy=(x4, y4), xytext=(x4, y4),fontsize=8,
# ...

# %% [markdown]
# # C1散点图

# %%
#读取文件
readFileName="pca战略坐标2-改.xlsx"
#读取excel
biaoname=sheet_name="C1"
df=pd.read_excel(readFileName, biaoname)

penguins_df=df

df.head(10)


#添加特定的分割线版本
#中文乱码解决
from pylab import mpl
mpl.rcParams['font.sans-serif'] = ['Times New Roman'] # 指定默认字体
mpl.rcParams['axes.unicode_minus'] = False # 解决保存图像是负号'-'显示为方块的问题


fig, ax = plt.subplots(figsize=(6,5),dpi=200)
#颜色定制
#3种颜色
# palette = ("#FF8C00", "#A034F0", "#159090")
palette = ("#515151")
#八种颜色
# palette = ("#FFBE0B", "#FB5607", "#FF006E","#8338EC","#3A86FF","#8338EC","#001524","#15616D")
#x=战略坐标偏移值  y=战略坐标重要值  hue为分类
sns.color_palette("pastel")
scatter = sns.scatterplot(data=penguins_df,x="Concentricity",y="Density",color=palette,
                          size="Size",ec="k",alpha=.9,ax=ax,linewidth=1)
    
scatter.legend()
# ax.text(.91,-.1,'\nVisualization by DataCharm',transform = ax.transAxes,
#         ha='center', va='center',fontsize = 7,color='black')

#自定义标签

handles,labels = scatter.get_legend_handles_labels()
labels_size =  labels[3:]

#添加单位
# labels_size = [str(int(i)/1000)+" kg" for i in labels_size]

scatter.legend(handles=handles[1:4] + handles[5:], labels=labels[1:4] + labels_size ,ncol=1,loc="lower right",title="Size",
               frameon=True,fontsize=7,markerscale=1,bbox_to_anchor=(1, 0.0))

plt.style.use('default')

# 添加特定分割线
 ## vlines: vertical 垂直于 x 轴的线，在变量'经济总量'的均值处开始画，
   ## y 轴的范围[1.5, 3]
  ## y 轴的范围[ymin, ymax]
    
    
#1添加象限说明  第一象限
# 在2,1处画个圆点，添加注释
x1=-100
y1=200

#可以加一个圆圈
# ax.plot([x2], [y2], 'o')
ax.plot([x1], [y1])
ax.annotate('Edge&Mature Research', xy=(x1, y1), xytext=(x1, y1),fontsize=8,
            arrowprops=dict(facecolor='black', shrink=0.05,color='red'))

#2添加象限说明  第二象限
# 在2,1处画个圆点，添加注释
x2=70
y2=200

ax.plot([x2], [y2])
ax.annotate('Core&Mature Research', xy=(x2, y2), xytext=(x2, y2),fontsize=8,
            arrowprops=dict(facecolor='black', shrink=0.05,color='red'))

#3添加象限说明  第三象限
# 在2,1处画个圆点，添加注释
x3=-100
y3=-180
ax.plot([x3], [y3])
ax.annotate('Edge&Non-mature Research', xy=(x3, y3), xytext=(x3, y3),fontsize=8,
            arrowprops=dict(facecolor='black', shrink=0.05,color='red'))

#4添加象限说明  第四象限
# 在2,1处画个圆点，添加注释
x4=40
y4=-180
ax.plot([x4], [y4])
ax.annotate('Core&Non-mature Research', xy=(x4, y4), xytext=(x4, y4),fontsize=8,
            arrowprops=dict(facecolor='black', shrink=0.05,color='red'))
    
    
  ##################################################################################################   
 #   制作聚类图  凸形边
x1=df['Concentricity']
y1=df['Density']

# plt.scatter(x2, y2)
x1=df['Concentricity']
y1=df['Density']
#定义凸边
def encircle(x,y, ax=None, **kw):
    if not ax: ax=plt.gca()
    #计算凸边    
    p = np.c_[x,y]
    hull = ConvexHull(p)
    #加边界
    poly = plt.Polygon(p[hull.vertices,:], **kw)
    ax.add_patch(poly)
#ec是线 fc是颜色
encircle(x1, y1, ec="k", fc=palette, alpha=0.3)
# encircle(x2, y2, ec="orange", fc="none")   
 ##################################################################################################       
   

plt.vlines(x=df['xian1'].mean(), ymin=-200, ymax=200, 
           colors='black', linewidth=1, linestyles='--')
plt.hlines(y=df['xian2'].mean(), xmin=-150, xmax=150,
           colors='black', linewidth=1, linestyles='--')
#网格线开关
# plt.grid(True)

from pylab import mpl
mpl.rcParams['font.sans-serif'] = ['Times New Roman'] # 指定默认字体
mpl.rcParams['axes.unicode_minus'] = False # 解决保存图像是负号'-'显示为方块的问题
plt.title(biaoname+' '+'Strategy Coordinate',fontsize=15)
plt.savefig('战略图'+'_'+biaoname+'.png', dpi=600, bbox_inches='tight',font_scale=1)
plt.show()
# Out:
# C:\Users\69493\AppData\Local\Temp\ipykernel_32028\3997611432.py:62: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   ax.annotate('Edge&Mature Research', xy=(x1, y1), xytext=(x1, y1),fontsize=8,
# C:\Users\69493\AppData\Local\Temp\ipykernel_32028\3997611432.py:71: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   ax.annotate('Core&Mature Research', xy=(x2, y2), xytext=(x2, y2),fontsize=8,
# C:\Users\69493\AppData\Local\Temp\ipykernel_32028\3997611432.py:79: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   ax.annotate('Edge&Non-mature Research', xy=(x3, y3), xytext=(x3, y3),fontsize=8,
# C:\Users\69493\AppData\Local\Temp\ipykernel_32028\3997611432.py:87: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   ax.annotate('Core&Non-mature Research', xy=(x4, y4), xytext=(x4, y4),fontsize=8,
# ...

# %% [markdown]
# # C2散点图

# %%
#读取文件
readFileName="pca战略坐标2-改.xlsx"
#读取excel
biaoname=sheet_name="C2"
df=pd.read_excel(readFileName, biaoname)

penguins_df=df

df.head(10)


#添加特定的分割线版本
#中文乱码解决
from pylab import mpl
mpl.rcParams['font.sans-serif'] = ['Times New Roman'] # 指定默认字体
mpl.rcParams['axes.unicode_minus'] = False # 解决保存图像是负号'-'显示为方块的问题


fig, ax = plt.subplots(figsize=(6,5),dpi=200)
#颜色定制
#3种颜色
# palette = ("#FF8C00", "#A034F0", "#159090")
palette = ("#1a6fdf")
#八种颜色
# palette = ("#FFBE0B", "#FB5607", "#FF006E","#8338EC","#3A86FF","#8338EC","#001524","#15616D")
#x=战略坐标偏移值  y=战略坐标重要值  hue为分类
sns.color_palette("pastel")
scatter = sns.scatterplot(data=penguins_df,x="Concentricity",y="Density",color=palette,
                          size="Size",ec="k",alpha=.9,ax=ax,linewidth=1)
    
scatter.legend()
# ax.text(.91,-.1,'\nVisualization by DataCharm',transform = ax.transAxes,
#         ha='center', va='center',fontsize = 7,color='black')

#自定义标签

handles,labels = scatter.get_legend_handles_labels()
labels_size =  labels[5:]

#添加单位
# labels_size = [str(int(i)/1000)+" kg" for i in labels_size]

scatter.legend(handles=handles[1:4] + handles[5:], labels=labels[1:4] + labels_size ,ncol=1,loc="lower right",title="Size",
               frameon=True,fontsize=7,markerscale=1,bbox_to_anchor=(1, 0.0))
plt.style.use('default')

# 添加特定分割线
 ## vlines: vertical 垂直于 x 轴的线，在变量'经济总量'的均值处开始画，
   ## y 轴的范围[1.5, 3]
  ## y 轴的范围[ymin, ymax]
    
    
#1添加象限说明  第一象限
# 在2,1处画个圆点，添加注释
x1=-100
y1=200

#可以加一个圆圈
# ax.plot([x2], [y2], 'o')
ax.plot([x1], [y1])
ax.annotate('Edge&Mature Research', xy=(x1, y1), xytext=(x1, y1),fontsize=8,
            arrowprops=dict(facecolor='black', shrink=0.05,color='red'))

#2添加象限说明  第二象限
# 在2,1处画个圆点，添加注释
x2=70
y2=200

ax.plot([x2], [y2])
ax.annotate('Core&Mature Research', xy=(x2, y2), xytext=(x2, y2),fontsize=8,
            arrowprops=dict(facecolor='black', shrink=0.05,color='red'))

#3添加象限说明  第三象限
# 在2,1处画个圆点，添加注释
x3=-100
y3=-180
ax.plot([x3], [y3])
ax.annotate('Edge&Non-mature Research', xy=(x3, y3), xytext=(x3, y3),fontsize=8,
            arrowprops=dict(facecolor='black', shrink=0.05,color='red'))

#4添加象限说明  第四象限
# 在2,1处画个圆点，添加注释
x4=40
y4=-180
ax.plot([x4], [y4])
ax.annotate('Core&Non-mature Research', xy=(x4, y4), xytext=(x4, y4),fontsize=8,
            arrowprops=dict(facecolor='black', shrink=0.05,color='red'))
    
##################################################################################################   
 #   制作聚类图  凸形边
x1=df['Concentricity']
y1=df['Density']

# plt.scatter(x2, y2)
x1=df['Concentricity']
y1=df['Density']
#定义凸边
def encircle(x,y, ax=None, **kw):
    if not ax: ax=plt.gca()
    #计算凸边    
    p = np.c_[x,y]
    hull = ConvexHull(p)
    #加边界
    poly = plt.Polygon(p[hull.vertices,:], **kw)
    ax.add_patch(poly)
#ec是线 fc是颜色
encircle(x1, y1, ec="k", fc=palette, alpha=0.3)
# encircle(x2, y2, ec="orange", fc="none")   
 ##################################################################################################       


plt.vlines(x=df['xian1'].mean(), ymin=-200, ymax=200, 
           colors='black', linewidth=1, linestyles='--')
plt.hlines(y=df['xian2'].mean(), xmin=-150, xmax=150,
           colors='black', linewidth=1, linestyles='--')
#网格线开关
# plt.grid(True)

from pylab import mpl
mpl.rcParams['font.sans-serif'] = ['Times New Roman'] # 指定默认字体
mpl.rcParams['axes.unicode_minus'] = False # 解决保存图像是负号'-'显示为方块的问题
plt.title(biaoname+' '+'Strategy Coordinate',fontsize=15)
plt.savefig('战略图'+'_'+biaoname+'.png', dpi=600, bbox_inches='tight',font_scale=1)
plt.show()
# Out:
# C:\Users\69493\AppData\Local\Temp\ipykernel_28328\2099121875.py:61: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   ax.annotate('Edge&Mature Research', xy=(x1, y1), xytext=(x1, y1),fontsize=8,
# C:\Users\69493\AppData\Local\Temp\ipykernel_28328\2099121875.py:70: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   ax.annotate('Core&Mature Research', xy=(x2, y2), xytext=(x2, y2),fontsize=8,
# C:\Users\69493\AppData\Local\Temp\ipykernel_28328\2099121875.py:78: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   ax.annotate('Edge&Non-mature Research', xy=(x3, y3), xytext=(x3, y3),fontsize=8,
# C:\Users\69493\AppData\Local\Temp\ipykernel_28328\2099121875.py:86: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   ax.annotate('Core&Non-mature Research', xy=(x4, y4), xytext=(x4, y4),fontsize=8,
# ...

# %% [markdown]
# # C3散点图
# df=pd.read_excel(readFileName, sheet_name="C3")
# xl=sheet_name="C3"
# print(xl)

# %%
#读取文件
readFileName="pca战略坐标2-改.xlsx"
#读取excel

biaoname=sheet_name="C3"
df=pd.read_excel(readFileName, biaoname)

penguins_df=df

df.head(10)


#添加特定的分割线版本
#中文乱码解决
from pylab import mpl
mpl.rcParams['font.sans-serif'] = ['Times New Roman'] # 指定默认字体
mpl.rcParams['axes.unicode_minus'] = False # 解决保存图像是负号'-'显示为方块的问题


fig, ax = plt.subplots(figsize=(6,5),dpi=200)
#颜色定制
#3种颜色
# palette = ("#FF8C00", "#A034F0", "#159090")
palette = ("#00cbcc")
#八种颜色
# palette = ("#FFBE0B", "#FB5607", "#FF006E","#8338EC","#3A86FF","#8338EC","#001524","#15616D")
#x=战略坐标偏移值  y=战略坐标重要值  hue为分类
sns.color_palette("pastel")
scatter = sns.scatterplot(data=penguins_df,x="Concentricity",y="Density",color=palette,
                          size="Size",ec="k",alpha=.9,ax=ax,linewidth=1)
    
scatter.legend()
# ax.text(.91,-.1,'\nVisualization by DataCharm',transform = ax.transAxes,
#         ha='center', va='center',fontsize = 7,color='black')

#自定义标签

handles,labels = scatter.get_legend_handles_labels()
labels_size =  labels[5:]

#添加单位
# labels_size = [str(int(i)/1000)+" kg" for i in labels_size]

scatter.legend(handles=handles[1:4] + handles[5:], labels=labels[1:4] + labels_size ,ncol=1,loc="lower right",title="Size",
               frameon=True,fontsize=7,markerscale=1,bbox_to_anchor=(1, 0.0))

plt.style.use('default')

# 添加特定分割线
 ## vlines: vertical 垂直于 x 轴的线，在变量'经济总量'的均值处开始画，
   ## y 轴的范围[1.5, 3]
  ## y 轴的范围[ymin, ymax]
    
    
#1添加象限说明  第一象限
# 在2,1处画个圆点，添加注释
x1=-100
y1=200

#可以加一个圆圈
# ax.plot([x2], [y2], 'o')
ax.plot([x1], [y1])
ax.annotate('Edge&Mature Research', xy=(x1, y1), xytext=(x1, y1),fontsize=8,
            arrowprops=dict(facecolor='black', shrink=0.05,color='red'))

#2添加象限说明  第二象限
# 在2,1处画个圆点，添加注释
x2=70
y2=200

ax.plot([x2], [y2])
ax.annotate('Core&Mature Research', xy=(x2, y2), xytext=(x2, y2),fontsize=8,
            arrowprops=dict(facecolor='black', shrink=0.05,color='red'))

#3添加象限说明  第三象限
# 在2,1处画个圆点，添加注释
x3=-100
y3=-180
ax.plot([x3], [y3])
ax.annotate('Edge&Non-mature Research', xy=(x3, y3), xytext=(x3, y3),fontsize=8,
            arrowprops=dict(facecolor='black', shrink=0.05,color='red'))

#4添加象限说明  第四象限
# 在2,1处画个圆点，添加注释
x4=40
y4=-180
ax.plot([x4], [y4])
ax.annotate('Core&Non-mature Research', xy=(x4, y4), xytext=(x4, y4),fontsize=8,
            arrowprops=dict(facecolor='black', shrink=0.05,color='red'))
    
##################################################################################################   
 #   制作聚类图  凸形边
x1=df['Concentricity']
y1=df['Density']

# plt.scatter(x2, y2)
x1=df['Concentricity']
y1=df['Density']
#定义凸边
def encircle(x,y, ax=None, **kw):
    if not ax: ax=plt.gca()
    #计算凸边    
    p = np.c_[x,y]
    hull = ConvexHull(p)
    #加边界
    poly = plt.Polygon(p[hull.vertices,:], **kw)
    ax.add_patch(poly)
#ec是线 fc是颜色
encircle(x1, y1, ec="k", fc=palette, alpha=0.3)
# encircle(x2, y2, ec="orange", fc="none")   
 ##################################################################################################           
    

plt.vlines(x=df['xian1'].mean(), ymin=-200, ymax=200, 
           colors='black', linewidth=1, linestyles='--')
plt.hlines(y=df['xian2'].mean(), xmin=-150, xmax=150,
           colors='black', linewidth=1, linestyles='--')
#网格线开关
# plt.grid(True)

from pylab import mpl
mpl.rcParams['font.sans-serif'] = ['Times New Roman'] # 指定默认字体
mpl.rcParams['axes.unicode_minus'] = False # 解决保存图像是负号'-'显示为方块的问题
plt.title(biaoname+' '+'Strategy Coordinate',fontsize=15)
plt.savefig('战略图'+'_'+biaoname+'.png', dpi=600, bbox_inches='tight',font_scale=1)
plt.show()
# Out:
# C:\Users\69493\AppData\Local\Temp\ipykernel_32028\103727555.py:63: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   ax.annotate('Edge&Mature Research', xy=(x1, y1), xytext=(x1, y1),fontsize=8,
# C:\Users\69493\AppData\Local\Temp\ipykernel_32028\103727555.py:72: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   ax.annotate('Core&Mature Research', xy=(x2, y2), xytext=(x2, y2),fontsize=8,
# C:\Users\69493\AppData\Local\Temp\ipykernel_32028\103727555.py:80: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   ax.annotate('Edge&Non-mature Research', xy=(x3, y3), xytext=(x3, y3),fontsize=8,
# C:\Users\69493\AppData\Local\Temp\ipykernel_32028\103727555.py:88: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   ax.annotate('Core&Non-mature Research', xy=(x4, y4), xytext=(x4, y4),fontsize=8,
# ...

# %% [markdown]
# # C4散点图

# %%
#读取文件
readFileName="pca战略坐标2-改.xlsx"
#读取excel

biaoname=sheet_name="C4"
df=pd.read_excel(readFileName, biaoname)

penguins_df=df

df.head(10)


#添加特定的分割线版本
#中文乱码解决
from pylab import mpl
mpl.rcParams['font.sans-serif'] = ['Times New Roman'] # 指定默认字体
mpl.rcParams['axes.unicode_minus'] = False # 解决保存图像是负号'-'显示为方块的问题


fig, ax = plt.subplots(figsize=(6,5),dpi=200)
#颜色定制
#3种颜色
# palette = ("#FF8C00", "#A034F0", "#159090")
palette = ("#b177de")
#八种颜色
# palette = ("#FFBE0B", "#FB5607", "#FF006E","#8338EC","#3A86FF","#8338EC","#001524","#15616D")
#x=战略坐标偏移值  y=战略坐标重要值  hue为分类
sns.color_palette("pastel")
scatter = sns.scatterplot(data=penguins_df,x="Concentricity",y="Density",color=palette,
                          size="Size",ec="k",alpha=.9,ax=ax,linewidth=1)
    
scatter.legend()
# ax.text(.91,-.1,'\nVisualization by DataCharm',transform = ax.transAxes,
#         ha='center', va='center',fontsize = 7,color='black')

#自定义标签

handles,labels = scatter.get_legend_handles_labels()
labels_size =  labels[5:]

#添加单位
# labels_size = [str(int(i)/1000)+" kg" for i in labels_size]

scatter.legend(handles=handles[1:4] + handles[5:], labels=labels[1:4] + labels_size ,ncol=1,loc="lower right",title="Size",
               frameon=True,fontsize=7,markerscale=1,bbox_to_anchor=(1, 0.0))

plt.style.use('default')

# 添加特定分割线
 ## vlines: vertical 垂直于 x 轴的线，在变量'经济总量'的均值处开始画，
   ## y 轴的范围[1.5, 3]
  ## y 轴的范围[ymin, ymax]
    
    
#1添加象限说明  第一象限
# 在2,1处画个圆点，添加注释
x1=-100
y1=200

#可以加一个圆圈
# ax.plot([x2], [y2], 'o')
ax.plot([x1], [y1])
ax.annotate('Edge&Mature Research', xy=(x1, y1), xytext=(x1, y1),fontsize=8,
            arrowprops=dict(facecolor='black', shrink=0.05,color='red'))

#2添加象限说明  第二象限
# 在2,1处画个圆点，添加注释
x2=70
y2=200

ax.plot([x2], [y2])
ax.annotate('Core&Mature Research', xy=(x2, y2), xytext=(x2, y2),fontsize=8,
            arrowprops=dict(facecolor='black', shrink=0.05,color='red'))

#3添加象限说明  第三象限
# 在2,1处画个圆点，添加注释
x3=-100
y3=-180
ax.plot([x3], [y3])
ax.annotate('Edge&Non-mature Research', xy=(x3, y3), xytext=(x3, y3),fontsize=8,
            arrowprops=dict(facecolor='black', shrink=0.05,color='red'))

#4添加象限说明  第四象限
# 在2,1处画个圆点，添加注释
x4=40
y4=-180
ax.plot([x4], [y4])
ax.annotate('Core&Non-mature Research', xy=(x4, y4), xytext=(x4, y4),fontsize=8,
            arrowprops=dict(facecolor='black', shrink=0.05,color='red'))
    
    
##################################################################################################   
 #   制作聚类图  凸形边
x1=df['Concentricity']
y1=df['Density']

# plt.scatter(x2, y2)
x1=df['Concentricity']
y1=df['Density']
#定义凸边
def encircle(x,y, ax=None, **kw):
    if not ax: ax=plt.gca()
    #计算凸边    
    p = np.c_[x,y]
    hull = ConvexHull(p)
    #加边界
    poly = plt.Polygon(p[hull.vertices,:], **kw)
    ax.add_patch(poly)
#ec是线 fc是颜色
encircle(x1, y1, ec="k", fc=palette, alpha=0.3)
# encircle(x2, y2, ec="orange", fc="none")   
 ##################################################################################################           

plt.vlines(x=df['xian1'].mean(), ymin=-200, ymax=200, 
           colors='black', linewidth=1, linestyles='--')
plt.hlines(y=df['xian2'].mean(), xmin=-150, xmax=150,
           colors='black', linewidth=1, linestyles='--')
#网格线开关
# plt.grid(True)

from pylab import mpl
mpl.rcParams['font.sans-serif'] = ['Times New Roman'] # 指定默认字体
mpl.rcParams['axes.unicode_minus'] = False # 解决保存图像是负号'-'显示为方块的问题
plt.title(biaoname+' '+'Strategy Coordinate',fontsize=15)
plt.savefig('战略图'+'_'+biaoname+'.png', dpi=600, bbox_inches='tight',font_scale=1)
plt.show()
# Out:
# C:\Users\69493\AppData\Local\Temp\ipykernel_32028\1324893042.py:63: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   ax.annotate('Edge&Mature Research', xy=(x1, y1), xytext=(x1, y1),fontsize=8,
# C:\Users\69493\AppData\Local\Temp\ipykernel_32028\1324893042.py:72: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   ax.annotate('Core&Mature Research', xy=(x2, y2), xytext=(x2, y2),fontsize=8,
# C:\Users\69493\AppData\Local\Temp\ipykernel_32028\1324893042.py:80: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   ax.annotate('Edge&Non-mature Research', xy=(x3, y3), xytext=(x3, y3),fontsize=8,
# C:\Users\69493\AppData\Local\Temp\ipykernel_32028\1324893042.py:88: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   ax.annotate('Core&Non-mature Research', xy=(x4, y4), xytext=(x4, y4),fontsize=8,
# ...

# %% [markdown]
# # C5散点图

# %%
#读取文件
readFileName="pca战略坐标2-改.xlsx"
#读取excel

biaoname=sheet_name="C5"
df=pd.read_excel(readFileName, biaoname)

penguins_df=df

df.head(10)


#添加特定的分割线版本
#中文乱码解决
from pylab import mpl
mpl.rcParams['font.sans-serif'] = ['Times New Roman'] # 指定默认字体
mpl.rcParams['axes.unicode_minus'] = False # 解决保存图像是负号'-'显示为方块的问题


fig, ax = plt.subplots(figsize=(6,5),dpi=200)
#颜色定制
#3种颜色
# palette = ("#FF8C00", "#A034F0", "#159090")
palette = ("#cc9900")
#八种颜色
# palette = ("#FFBE0B", "#FB5607", "#FF006E","#8338EC","#3A86FF","#8338EC","#001524","#15616D")
#x=战略坐标偏移值  y=战略坐标重要值  hue为分类
sns.color_palette("pastel")
scatter = sns.scatterplot(data=penguins_df,x="Concentricity",y="Density",color=palette,
                          size="Size",ec="k",alpha=.9,ax=ax,linewidth=1)
    
scatter.legend()
# ax.text(.91,-.1,'\nVisualization by DataCharm',transform = ax.transAxes,
#         ha='center', va='center',fontsize = 7,color='black')

#自定义标签

handles,labels = scatter.get_legend_handles_labels()
labels_size =  labels[5:]

#添加单位
# labels_size = [str(int(i)/1000)+" kg" for i in labels_size]

scatter.legend(handles=handles[1:4] + handles[5:], labels=labels[1:4] + labels_size ,ncol=1,loc="lower right",title="Size",
               frameon=True,fontsize=7,markerscale=1,bbox_to_anchor=(1, 0.0))

plt.style.use('default')

# 添加特定分割线
 ## vlines: vertical 垂直于 x 轴的线，在变量'经济总量'的均值处开始画，
   ## y 轴的范围[1.5, 3]
  ## y 轴的范围[ymin, ymax]
    
    
#1添加象限说明  第一象限
# 在2,1处画个圆点，添加注释
x1=-100
y1=200

#可以加一个圆圈
# ax.plot([x2], [y2], 'o')
ax.plot([x1], [y1])
ax.annotate('Edge&Mature Research', xy=(x1, y1), xytext=(x1, y1),fontsize=8,
            arrowprops=dict(facecolor='black', shrink=0.05,color='red'))

#2添加象限说明  第二象限
# 在2,1处画个圆点，添加注释
x2=70
y2=200

ax.plot([x2], [y2])
ax.annotate('Core&Mature Research', xy=(x2, y2), xytext=(x2, y2),fontsize=8,
            arrowprops=dict(facecolor='black', shrink=0.05,color='red'))

#3添加象限说明  第三象限
# 在2,1处画个圆点，添加注释
x3=-100
y3=-180
ax.plot([x3], [y3])
ax.annotate('Edge&Non-mature Research', xy=(x3, y3), xytext=(x3, y3),fontsize=8,
            arrowprops=dict(facecolor='black', shrink=0.05,color='red'))

#4添加象限说明  第四象限
# 在2,1处画个圆点，添加注释
x4=40
y4=-180
ax.plot([x4], [y4])
ax.annotate('Core&Non-mature Research', xy=(x4, y4), xytext=(x4, y4),fontsize=8,
            arrowprops=dict(facecolor='black', shrink=0.05,color='red'))
    
##################################################################################################   
 #   制作聚类图  凸形边
x1=df['Concentricity']
y1=df['Density']

# plt.scatter(x2, y2)
x1=df['Concentricity']
y1=df['Density']
#定义凸边
def encircle(x,y, ax=None, **kw):
    if not ax: ax=plt.gca()
    #计算凸边    
    p = np.c_[x,y]
    hull = ConvexHull(p)
    #加边界
    poly = plt.Polygon(p[hull.vertices,:], **kw)
    ax.add_patch(poly)
#ec是线 fc是颜色
encircle(x1, y1, ec="k", fc=palette, alpha=0.3)
# encircle(x2, y2, ec="orange", fc="none")   
 ##################################################################################################           
    

plt.vlines(x=df['xian1'].mean(), ymin=-200, ymax=200, 
           colors='black', linewidth=1, linestyles='--')
plt.hlines(y=df['xian2'].mean(), xmin=-150, xmax=150,
           colors='black', linewidth=1, linestyles='--')
#网格线开关
# plt.grid(True)

from pylab import mpl
mpl.rcParams['font.sans-serif'] = ['Times New Roman'] # 指定默认字体
mpl.rcParams['axes.unicode_minus'] = False # 解决保存图像是负号'-'显示为方块的问题
plt.title(biaoname+' '+'Strategy Coordinate',fontsize=15)
plt.savefig('战略图'+'_'+biaoname+'.png', dpi=600, bbox_inches='tight',font_scale=1)
plt.show()
# Out:
# C:\Users\69493\AppData\Local\Temp\ipykernel_32028\3778242406.py:63: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   ax.annotate('Edge&Mature Research', xy=(x1, y1), xytext=(x1, y1),fontsize=8,
# C:\Users\69493\AppData\Local\Temp\ipykernel_32028\3778242406.py:72: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   ax.annotate('Core&Mature Research', xy=(x2, y2), xytext=(x2, y2),fontsize=8,
# C:\Users\69493\AppData\Local\Temp\ipykernel_32028\3778242406.py:80: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   ax.annotate('Edge&Non-mature Research', xy=(x3, y3), xytext=(x3, y3),fontsize=8,
# C:\Users\69493\AppData\Local\Temp\ipykernel_32028\3778242406.py:88: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   ax.annotate('Core&Non-mature Research', xy=(x4, y4), xytext=(x4, y4),fontsize=8,
# ...

# %% [markdown]
# # C6散点图

# %%
#读取文件
readFileName="pca战略坐标2-改.xlsx"
#读取excel

biaoname=sheet_name="C6"
df=pd.read_excel(readFileName, biaoname)

penguins_df=df

df.head(10)


#添加特定的分割线版本
#中文乱码解决
from pylab import mpl
mpl.rcParams['font.sans-serif'] = ['Times New Roman'] # 指定默认字体
mpl.rcParams['axes.unicode_minus'] = False # 解决保存图像是负号'-'显示为方块的问题


fig, ax = plt.subplots(figsize=(6,5),dpi=200)
#颜色定制
#3种颜色
# palette = ("#FF8C00", "#A034F0", "#159090")
palette = ("#7d4e4e")
#八种颜色
# palette = ("#FFBE0B", "#FB5607", "#FF006E","#8338EC","#3A86FF","#8338EC","#001524","#15616D")
#x=战略坐标偏移值  y=战略坐标重要值  hue为分类
sns.color_palette("pastel")
scatter = sns.scatterplot(data=penguins_df,x="Concentricity",y="Density",color=palette,
                          size="Size",ec="k",alpha=.9,ax=ax,linewidth=1)
    
scatter.legend()
# ax.text(.91,-.1,'\nVisualization by DataCharm',transform = ax.transAxes,
#         ha='center', va='center',fontsize = 7,color='black')

#自定义标签

handles,labels = scatter.get_legend_handles_labels()
labels_size =  labels[5:]

#添加单位
# labels_size = [str(int(i)/1000)+" kg" for i in labels_size]

scatter.legend(handles=handles[1:4] + handles[5:], labels=labels[1:4] + labels_size ,ncol=1,loc="lower right",title="Size",
               frameon=True,fontsize=7,markerscale=1,bbox_to_anchor=(1, 0.0))

plt.style.use('default')

# 添加特定分割线
 ## vlines: vertical 垂直于 x 轴的线，在变量'经济总量'的均值处开始画，
   ## y 轴的范围[1.5, 3]
  ## y 轴的范围[ymin, ymax]
    
    
#1添加象限说明  第一象限
# 在2,1处画个圆点，添加注释
x1=-100
y1=200

#可以加一个圆圈
# ax.plot([x2], [y2], 'o')
ax.plot([x1], [y1])
ax.annotate('Edge&Mature Research', xy=(x1, y1), xytext=(x1, y1),fontsize=8,
            arrowprops=dict(facecolor='black', shrink=0.05,color='red'))

#2添加象限说明  第二象限
# 在2,1处画个圆点，添加注释
x2=70
y2=200

ax.plot([x2], [y2])
ax.annotate('Core&Mature Research', xy=(x2, y2), xytext=(x2, y2),fontsize=8,
            arrowprops=dict(facecolor='black', shrink=0.05,color='red'))

#3添加象限说明  第三象限
# 在2,1处画个圆点，添加注释
x3=-100
y3=-180
ax.plot([x3], [y3])
ax.annotate('Edge&Non-mature Research', xy=(x3, y3), xytext=(x3, y3),fontsize=8,
            arrowprops=dict(facecolor='black', shrink=0.05,color='red'))

#4添加象限说明  第四象限
# 在2,1处画个圆点，添加注释
x4=40
y4=-180
ax.plot([x4], [y4])
ax.annotate('Core&Non-mature Research', xy=(x4, y4), xytext=(x4, y4),fontsize=8,
            arrowprops=dict(facecolor='black', shrink=0.05,color='red'))
    
    
  ##################################################################################################   
 #   制作聚类图  凸形边
x1=df['Concentricity']
y1=df['Density']

# plt.scatter(x2, y2)
x1=df['Concentricity']
y1=df['Density']
#定义凸边
def encircle(x,y, ax=None, **kw):
    if not ax: ax=plt.gca()
    #计算凸边    
    p = np.c_[x,y]
    hull = ConvexHull(p)
    #加边界
    poly = plt.Polygon(p[hull.vertices,:], **kw)
    ax.add_patch(poly)
#ec是线 fc是颜色
encircle(x1, y1, ec="k", fc=palette, alpha=0.3)
# encircle(x2, y2, ec="orange", fc="none")   
 ##################################################################################################         

plt.vlines(x=df['xian1'].mean(), ymin=-200, ymax=200, 
           colors='black', linewidth=1, linestyles='--')
plt.hlines(y=df['xian2'].mean(), xmin=-150, xmax=150,
           colors='black', linewidth=1, linestyles='--')
#网格线开关
# plt.grid(True)

from pylab import mpl
mpl.rcParams['font.sans-serif'] = ['Times New Roman'] # 指定默认字体
mpl.rcParams['axes.unicode_minus'] = False # 解决保存图像是负号'-'显示为方块的问题
plt.title(biaoname+' '+'Strategy Coordinate',fontsize=15)
plt.savefig('战略图'+'_'+biaoname+'.png', dpi=600, bbox_inches='tight',font_scale=1)
plt.show()
# Out:
# C:\Users\69493\AppData\Local\Temp\ipykernel_32028\637825680.py:63: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   ax.annotate('Edge&Mature Research', xy=(x1, y1), xytext=(x1, y1),fontsize=8,
# C:\Users\69493\AppData\Local\Temp\ipykernel_32028\637825680.py:72: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   ax.annotate('Core&Mature Research', xy=(x2, y2), xytext=(x2, y2),fontsize=8,
# C:\Users\69493\AppData\Local\Temp\ipykernel_32028\637825680.py:80: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   ax.annotate('Edge&Non-mature Research', xy=(x3, y3), xytext=(x3, y3),fontsize=8,
# C:\Users\69493\AppData\Local\Temp\ipykernel_32028\637825680.py:88: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   ax.annotate('Core&Non-mature Research', xy=(x4, y4), xytext=(x4, y4),fontsize=8,
# ...

# %% [markdown]
# # C7散点图

# %%
#读取文件
readFileName="pca战略坐标2-改.xlsx"
#读取excel

biaoname=sheet_name="C7"
df=pd.read_excel(readFileName, biaoname)

penguins_df=df

df.head(10)


#添加特定的分割线版本
#中文乱码解决
from pylab import mpl
mpl.rcParams['font.sans-serif'] = ['Times New Roman'] # 指定默认字体
mpl.rcParams['axes.unicode_minus'] = False # 解决保存图像是负号'-'显示为方块的问题


fig, ax = plt.subplots(figsize=(6,5),dpi=200)
#颜色定制
#3种颜色
# palette = ("#FF8C00", "#A034F0", "#159090")
palette = ("#f14040")
#八种颜色
# palette = ("#FFBE0B", "#FB5607", "#FF006E","#8338EC","#3A86FF","#8338EC","#001524","#15616D")
#x=战略坐标偏移值  y=战略坐标重要值  hue为分类
sns.color_palette("pastel")
scatter = sns.scatterplot(data=penguins_df,x="Concentricity",y="Density",color=palette,
                          size="Size",ec="k",alpha=.9,ax=ax,linewidth=1)
    
scatter.legend()
# ax.text(.91,-.1,'\nVisualization by DataCharm',transform = ax.transAxes,
#         ha='center', va='center',fontsize = 7,color='black')

#自定义标签

handles,labels = scatter.get_legend_handles_labels()
labels_size =  labels[5:]

#添加单位
# labels_size = [str(int(i)/1000)+" kg" for i in labels_size]

scatter.legend(handles=handles[1:4] + handles[5:], labels=labels[1:4] + labels_size ,ncol=1,loc="lower right",title="Size",
               frameon=True,fontsize=7,markerscale=1,bbox_to_anchor=(1, 0.0))

plt.style.use('default')

# 添加特定分割线
 ## vlines: vertical 垂直于 x 轴的线，在变量'经济总量'的均值处开始画，
   ## y 轴的范围[1.5, 3]
  ## y 轴的范围[ymin, ymax]
    
    
#1添加象限说明  第一象限
# 在2,1处画个圆点，添加注释
x1=-100
y1=200

#可以加一个圆圈
# ax.plot([x2], [y2], 'o')
ax.plot([x1], [y1])
ax.annotate('Edge&Mature Research', xy=(x1, y1), xytext=(x1, y1),fontsize=8,
            arrowprops=dict(facecolor='black', shrink=0.05,color='red'))

#2添加象限说明  第二象限
# 在2,1处画个圆点，添加注释
x2=70
y2=200

ax.plot([x2], [y2])
ax.annotate('Core&Mature Research', xy=(x2, y2), xytext=(x2, y2),fontsize=8,
            arrowprops=dict(facecolor='black', shrink=0.05,color='red'))

#3添加象限说明  第三象限
# 在2,1处画个圆点，添加注释
x3=-100
y3=-180
ax.plot([x3], [y3])
ax.annotate('Edge&Non-mature Research', xy=(x3, y3), xytext=(x3, y3),fontsize=8,
            arrowprops=dict(facecolor='black', shrink=0.05,color='red'))

#4添加象限说明  第四象限
# 在2,1处画个圆点，添加注释
x4=40
y4=-180
ax.plot([x4], [y4])
ax.annotate('Core&Non-mature Research', xy=(x4, y4), xytext=(x4, y4),fontsize=8,
            arrowprops=dict(facecolor='black', shrink=0.05,color='red'))
    
##################################################################################################   
 #   制作聚类图  凸形边
x1=df['Concentricity']
y1=df['Density']

# plt.scatter(x2, y2)
x1=df['Concentricity']
y1=df['Density']
#定义凸边
def encircle(x,y, ax=None, **kw):
    if not ax: ax=plt.gca()
    #计算凸边    
    p = np.c_[x,y]
    hull = ConvexHull(p)
    #加边界
    poly = plt.Polygon(p[hull.vertices,:], **kw)
    ax.add_patch(poly)
#ec是线 fc是颜色
encircle(x1, y1, ec="k", fc=palette, alpha=0.3)
# encircle(x2, y2, ec="orange", fc="none")   
 ##################################################################################################           
    

plt.vlines(x=df['xian1'].mean(), ymin=-200, ymax=200, 
           colors='black', linewidth=1, linestyles='--')
plt.hlines(y=df['xian2'].mean(), xmin=-150, xmax=150,
           colors='black', linewidth=1, linestyles='--')
#网格线开关
# plt.grid(True)

from pylab import mpl
mpl.rcParams['font.sans-serif'] = ['Times New Roman'] # 指定默认字体
mpl.rcParams['axes.unicode_minus'] = False # 解决保存图像是负号'-'显示为方块的问题
plt.title(biaoname+' '+'Strategy Coordinate',fontsize=15)
plt.savefig('战略图'+'_'+biaoname+'.png', dpi=600, bbox_inches='tight',font_scale=1)
plt.show()
# Out:
# C:\Users\69493\AppData\Local\Temp\ipykernel_32028\4079378356.py:63: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   ax.annotate('Edge&Mature Research', xy=(x1, y1), xytext=(x1, y1),fontsize=8,
# C:\Users\69493\AppData\Local\Temp\ipykernel_32028\4079378356.py:72: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   ax.annotate('Core&Mature Research', xy=(x2, y2), xytext=(x2, y2),fontsize=8,
# C:\Users\69493\AppData\Local\Temp\ipykernel_32028\4079378356.py:80: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   ax.annotate('Edge&Non-mature Research', xy=(x3, y3), xytext=(x3, y3),fontsize=8,
# C:\Users\69493\AppData\Local\Temp\ipykernel_32028\4079378356.py:88: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   ax.annotate('Core&Non-mature Research', xy=(x4, y4), xytext=(x4, y4),fontsize=8,
# ...

# %% [markdown]
# # 汇总图

# %%
import matplotlib.pyplot as plt
import numpy as np; np.random.seed(1)
from scipy.spatial import ConvexHull


readFileName="pca战略坐标2-改.xlsx"
#读取excel

biaoname=sheet_name="C7"
df=pd.read_excel(readFileName, biaoname)

penguins_df=df
#添加特定的分割线版本
#中文乱码解决
from pylab import mpl
mpl.rcParams['font.sans-serif'] = ['Times New Roman'] # 指定默认字体
mpl.rcParams['axes.unicode_minus'] = False # 解决保存图像是负号'-'显示为方块的问题


fig, ax = plt.subplots(figsize=(6,5),dpi=200)
#颜色定制
#3种颜色
# palette = ("#FF8C00", "#A034F0", "#159090")
palette = ("#f14040")
#八种颜色
# palette = ("#FFBE0B", "#FB5607", "#FF006E","#8338EC","#3A86FF","#8338EC","#001524","#15616D")
#x=战略坐标偏移值  y=战略坐标重要值  hue为分类
sns.color_palette("pastel")
scatter = sns.scatterplot(data=penguins_df,x="Concentricity",y="Density",color=palette,
                          size="Size",ec="k",alpha=.9,ax=ax,linewidth=1)

x1=df['Concentricity']
y1=df['Density']
# x1, y1 = np.random.normal(loc=5, scale=2, size=(2,15))
# x2, y2 = np.random.normal(loc=8, scale=2.5, size=(2,18))

plt.scatter = sns.scatterplot(data=penguins_df,x="Concentricity",y="Density",color=palette,
                          size="Size",ec="k",alpha=.9,ax=ax,linewidth=1)
# plt.scatter(x2, y2)
x1=df['Concentricity']
y1=df['Density']
def encircle(x,y, ax=None, **kw):
    if not ax: ax=plt.gca()
    p = np.c_[x,y]
    hull = ConvexHull(p)
    poly = plt.Polygon(p[hull.vertices,:], **kw)
    ax.add_patch(poly)

encircle(x1, y1, ec="k", fc="gold", alpha=0.2)
encircle(x2, y2, ec="orange", fc="none")

plt.show()

# %%
import os
print(os.path.abspath('.'))
# Out:
# C:\Users\69493\00 EDA可视化\散点图\00-战略散点图-PPP定制\战略坐标带聚类
